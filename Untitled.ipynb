# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
user = pd.read_csv('data/user.csv', sep='\t')

# %%
user.head(10)
# Out:
#    user_id     age  sex  user_lv_cd user_reg_dt
# 0       54      -1    2           1   2016/1/26
# 1       79  36-45岁    2           2   2016/1/27
# 2      100  16-25岁    2           3   2016/1/27
# 3      266   15岁以下    2           2   2016/1/29
# 4      333      -1    2           4   2016/1/30
# 5      605  26-35岁    2           2    2016/2/1
# 6      638  26-35岁    0           5   2010/8/12
# 7      686      -1    2           1    2016/2/1
# 8      692  16-25岁    2           2    2016/2/1
# 9      819  26-35岁    2           3    2016/2/2

# %%
user.sex.value_counts().plot(kind='bar') # 2 unknown, 1 female, 0 male

# %%
user.user_lv_cd.value_counts().plot(kind='bar') # 等级

# %%
user.age.value_counts().plot(kind='bar') # -1表示未知

# %%
comment = pd.read_csv('data/JData_Comment.csv')

# %%
comment['comment_num'].value_counts().plot(kind='bar') 
# 0表示无评论，1表示有1条评论， 2表示有2-10条评论， 3表示有11-50条评论， 4表示大于50条评论

# %%
bad_product = comment[comment['has_bad_comment']==1]

# %%
action2 = pd.read_csv('data/JData_Action_201602.csv')
action31 = pd.read_csv('data/JData_Action_201603.csv')
action32 = pd.read_csv('data/JData_Action_201603_extra.csv')
action4 = pd.read_csv('data/JData_Action_201604.csv')

# %%
action2.type.value_counts().plot(kind='bar')

# %%
action31.type.value_counts().plot(kind='bar')

# %%
action32.type.value_counts().plot(kind='bar')

# %%
action4.type.value_counts().plot(kind='bar')

# %%
action2[(action2['type']!=6) & (action2['type']!=1)]['type'].value_counts().plot(kind='bar')

# %%
action31[(action31['type']!=6) & (action31['type']!=1)]['type'].value_counts().plot(kind='bar')

# %%
action4[(action4['type']!=6) & (action4['type']!=1)]['type'].value_counts().plot(kind='bar')
